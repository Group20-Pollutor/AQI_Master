# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### **Loading The Dataset**

# %%
df=pd.read_csv("merged.csv")

# %%
df.head(10)
#first 10 values
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx    NH3     CO  \
# 0  Bengaluru  2015-01-01    NaN   NaN   3.26  17.33  10.88  20.36   0.33
# 1  Bengaluru  2015-01-02    NaN   NaN   6.05  19.73  14.14  23.74   1.35
# 2  Bengaluru  2015-01-03    NaN   NaN  11.91  19.88  20.72   4.32  17.40
# 3  Bengaluru  2015-01-04    NaN   NaN   7.45  21.61  16.88   0.87   5.05
# 4  Bengaluru  2015-01-05    NaN   NaN   9.52  22.17  21.76  31.38   1.83
# 5  Bengaluru  2015-01-06    NaN   NaN   6.60  23.20  16.24  26.35   0.52
# 6  Bengaluru  2015-01-07    NaN   NaN  22.60  28.66  30.84  22.73   1.46
# 7  Bengaluru  2015-01-08    NaN   NaN   7.50  31.10  21.16  38.67   2.30
# 8  Bengaluru  2015-01-09    NaN   NaN   6.75  25.98  15.03  23.48   0.54
# 9  Bengaluru  2015-01-10    NaN   NaN   3.38  29.23  16.76  34.17   1.69
#
#      SO2     O3  Benzene  Toluene  Xylene  AQI AQI_Bucket  Temperature  \
# 0   3.54  10.73     0.56     4.64     NaN  NaN        NaN         22.3
# ...

# %%
df.shape
#size of the data
# Out:
# (2009, 18)

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1863.000000  1649.000000  2003.000000  2003.000000  2005.000000
# mean     35.819828    83.243287     9.409136    27.995042    19.717092
# std      22.073252    38.105868     7.470543    13.286276    15.082800
# min       1.720000     8.220000     0.460000     3.000000     0.000000
# 25%      21.295000    56.410000     5.000000    18.790000     8.450000
# 50%      30.920000    77.360000     7.520000    26.920000    19.140000
# 75%      44.250000   103.850000    11.695000    34.175000    28.570000
# max     313.590000   351.510000    95.190000   142.350000   147.060000
#
#                NH3           CO          SO2           O3      Benzene  \
# count  1806.000000  1998.000000  2003.000000  1865.000000  1743.000000
# mean     21.977176     1.838634     5.519021    32.868086     3.222553
# std      12.739766     3.970001     4.185759    18.404404    16.323820
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2009 entries, 0 to 2008
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         2009 non-null   object
#  1   Date         2009 non-null   object
#  2   PM2.5        1863 non-null   float64
#  3   PM10         1649 non-null   float64
#  4   NO           2003 non-null   float64
#  5   NO2          2003 non-null   float64
#  6   NOx          2005 non-null   float64
#  7   NH3          1806 non-null   float64
#  8   CO           1998 non-null   float64
#  9   SO2          2003 non-null   float64
#  10  O3           1865 non-null   float64
#  11  Benzene      1743 non-null   float64
#  12  Toluene      1916 non-null   float64
#  13  Xylene       0 non-null      float64
#  14  AQI          1910 non-null   float64
#  15  AQI_Bucket   1910 non-null   object
#  16  Temperature  1022 non-null   float64
#  17  Humidity     1022 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5           146
# PM10            360
# NO                6
# NO2               6
# NOx               4
# NH3             203
# CO               11
# SO2               6
# O3              144
# Benzene         266
# Toluene          93
# Xylene         2009
# AQI              99
# AQI_Bucket       99
# Temperature     987
# Humidity        987
# dtype: int64

# %% [markdown]
# **HeatMap for null values**

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df=df.drop(['PM10','NO','NOx','NH3','O3','Benzene','Toluene','Xylene'],axis=1)
#dropping unwanted values

# %%
# df.head()
# Out:
#         City        Date  PM2.5    NO2     CO    SO2  AQI AQI_Bucket  \
# 0  Bengaluru  2015-01-01    NaN  17.33   0.33   3.54  NaN        NaN
# 1  Bengaluru  2015-01-02    NaN  19.73   1.35   3.97  NaN        NaN
# 2  Bengaluru  2015-01-03    NaN  19.88  17.40  13.61  NaN        NaN
# 3  Bengaluru  2015-01-04    NaN  21.61   5.05   6.52  NaN        NaN
# 4  Bengaluru  2015-01-05    NaN  22.17   1.83   4.71  NaN        NaN
#
#    Temperature  Humidity
# 0         22.3      77.0
# 1         22.2      71.0
# 2         22.1      76.0
# 3          NaN       NaN
# 4          NaN       NaN

# %%
df['Temperature']=df["Temperature"].fillna(method='bfill')
df['Humidity']=df["Humidity"].fillna(method='bfill')

# %%
# df.head()
# Out:
#         City        Date  PM2.5    NO2     CO    SO2  AQI AQI_Bucket  \
# 0  Bengaluru  2015-01-01    NaN  17.33   0.33   3.54  NaN        NaN
# 1  Bengaluru  2015-01-02    NaN  19.73   1.35   3.97  NaN        NaN
# 2  Bengaluru  2015-01-03    NaN  19.88  17.40  13.61  NaN        NaN
# 3  Bengaluru  2015-01-04    NaN  21.61   5.05   6.52  NaN        NaN
# 4  Bengaluru  2015-01-05    NaN  22.17   1.83   4.71  NaN        NaN
#
#    Temperature  Humidity
# 0         22.3      77.0
# 1         22.2      71.0
# 2         22.1      76.0
# 3         21.9      60.0
# 4         21.9      60.0

# %%
df=df.dropna()
#drop NaN values

# %%
df.isnull().sum()
# Out:
# City           0
# Date           0
# PM2.5          0
# NO2            0
# CO             0
# SO2            0
# AQI            0
# AQI_Bucket     0
# Temperature    0
# Humidity       0
# dtype: int64

# %%
df.shape
# Out:
# (1846, 10)

# %%
print(df.iloc[:,1])
# Out:
# 79      2015-03-21
# 80      2015-03-22
# 81      2015-03-23
# 82      2015-03-24
# 83      2015-03-25
#            ...
# 2004    2020-06-27
# 2005    2020-06-28
# 2006    2020-06-29
# 2007    2020-06-30
# 2008    2020-07-01
# Name: Date, Length: 1846, dtype: object

# %%
# df.iloc[:,["Humidity",'Temperature','CO','NO2','SO2','PM2.5']]
df=df.iloc[:,[0,1,9,8,4,3,5,2,6,7]]

# %%
df.head()
# Out:
#          City        Date  Humidity  Temperature     CO    NO2   SO2  PM2.5  \
# 79  Bengaluru  2015-03-21      26.0         27.1   3.89  27.00  1.94  48.59
# 80  Bengaluru  2015-03-22      43.0         27.9  11.29  22.39  2.05  47.38
# 81  Bengaluru  2015-03-23      43.0         27.9   9.95  26.35  6.30  65.65
# 82  Bengaluru  2015-03-24      43.0         27.9   1.46  29.87  6.07  60.47
# 83  Bengaluru  2015-03-25      43.0         27.9  10.05  23.57  4.98  62.56
#
#       AQI    AQI_Bucket
# 79   91.0  Satisfactory
# 80  120.0      Moderate
# 81  154.0      Moderate
# 82  119.0      Moderate
# 83  232.0          Poor

# %%
sns.pairplot(df)
#plot of correlation between the parameters

# %%
df.corr()
#checking correlation
# Out:
#              Humidity  Temperature        CO       NO2       SO2     PM2.5  \
# Humidity     1.000000    -0.474009  0.100594 -0.326297 -0.073777 -0.304169
# Temperature -0.474009     1.000000 -0.017743 -0.183014 -0.071480  0.010854
# CO           0.100594    -0.017743  1.000000 -0.196070 -0.120651 -0.090791
# NO2         -0.326297    -0.183014 -0.196070  1.000000  0.191092  0.407545
# SO2         -0.073777    -0.071480 -0.120651  0.191092  1.000000  0.097007
# PM2.5       -0.304169     0.010854 -0.090791  0.407545  0.097007  1.000000
# AQI         -0.235011     0.072039  0.383223  0.207761  0.007105  0.426591
#
#                   AQI
# Humidity    -0.235011
# Temperature  0.072039
# CO           0.383223
# NO2          0.207761
# SO2          0.007105
# PM2.5        0.426591
# AQI          1.000000

# %%
corrmat=df.corr()
corr_features=corrmat.index
plt.figure(figsize=(10,10))
corr_map=sns.heatmap(df[corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#           Humidity  Temperature           CO          NO2          SO2  \
# count  1846.000000  1846.000000  1846.000000  1846.000000  1846.000000
# mean     64.475623    24.353738     1.698868    28.570271     5.306446
# std      15.263084     2.239772     3.682716    13.360768     2.474314
# min      21.000000    18.900000     0.000000     4.380000     0.730000
# 25%      54.000000    22.900000     0.730000    19.292500     3.850000
# 50%      67.000000    24.000000     0.920000    27.560000     5.070000
# 75%      76.000000    25.600000     1.147500    35.075000     6.397500
# max      97.000000    31.200000    48.070000   142.350000    29.110000
#
#             PM2.5          AQI
# count  1846.00000  1846.000000
# mean     35.91156    95.375948
# std      22.14180    39.753871
# min       1.72000    26.000000
# 25%      21.29250    67.000000
# 50%      31.01500    87.000000
# 75%      44.31000   112.000000
# max     313.59000   352.000000

# %%
df.head()
# Out:
#          City        Date  Humidity  Temperature     CO    NO2   SO2  PM2.5  \
# 79  Bengaluru  2015-03-21      26.0         27.1   3.89  27.00  1.94  48.59
# 80  Bengaluru  2015-03-22      43.0         27.9  11.29  22.39  2.05  47.38
# 81  Bengaluru  2015-03-23      43.0         27.9   9.95  26.35  6.30  65.65
# 82  Bengaluru  2015-03-24      43.0         27.9   1.46  29.87  6.07  60.47
# 83  Bengaluru  2015-03-25      43.0         27.9  10.05  23.57  4.98  62.56
#
#       AQI    AQI_Bucket
# 79   91.0  Satisfactory
# 80  120.0      Moderate
# 81  154.0      Moderate
# 82  119.0      Moderate
# 83  232.0          Poor

# %%
X=df.iloc[:,[2,3,4,5,6,7]]
y=df.iloc[:,8]

# %%
print(X)
# Out:
#       Humidity  Temperature     CO    NO2   SO2  PM2.5
# 79        26.0         27.1   3.89  27.00  1.94  48.59
# 80        43.0         27.9  11.29  22.39  2.05  47.38
# 81        43.0         27.9   9.95  26.35  6.30  65.65
# 82        43.0         27.9   1.46  29.87  6.07  60.47
# 83        43.0         27.9  10.05  23.57  4.98  62.56
# ...        ...          ...    ...    ...   ...    ...
# 2004      78.0         24.4   0.67  13.68  7.29  16.60
# 2005      74.0         24.7   0.66  10.33  6.60  20.44
# 2006      74.0         24.7   0.56  12.12  6.33  28.68
# 2007      74.0         24.7   0.56  12.69  6.45  14.47
# 2008      74.0         24.7   0.54  13.25  6.66  17.50
#
# [1846 rows x 6 columns]

# %% [markdown]
# ***Feature Importance***

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.10660549 0.07199432 0.39158642 0.09112796 0.07306019 0.26562562]

# %%
feature_importance=pd.Series(model.feature_importances_,index=X.columns)
feature_importance.nlargest(20).plot(kind='bar')
plt.show()

# %%
sns.distplot(y)
# Out:
# c:\users\abhis\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.9400661869961451

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.44175641003068244

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.3389297276289205

# %% [markdown]
# **Model Evaluation**

# %%
y_predict=regressor.predict(X_test)

# %%
sns.distplot(y_test-y_predict)
# Out:
# c:\users\abhis\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
plt.scatter(y_test,y_predict)

# %%
# fig=plt.figure(figsize=(12,8),dpi=200)
# axes=fig.add_axes([0,0,1,1])
# axes.plot(range(50), y_test[0:50], label='test')
# axes.plot(range(50),y_predict[0:50],label="Prediction")
# plt.legend()
# plt.show()

# %% [markdown]
# ***Hyperparameter Tuning***

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators= [ int(x) for x in np.linspace(100,1200,num=12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
rf_random.best_score_
# Out:
# -665.7580747881689

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# c:\users\abhis\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# **EVALUATION METRICS**

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 16.398052333974626
# MSE: 728.116676979514
# RMSE: 26.983637208121404

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_predict))
print('MSE:', metrics.mean_squared_error(y_test, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# MAE: 17.04761732851986
# MSE: 818.2026418772564
# RMSE: 28.604241676318853

# %%
fig=plt.figure(figsize=(12,8),dpi=200)
axes=fig.add_axes([0,0,1,1])
axes.plot(range(50), y_test[0:50], label='test')
axes.plot(range(50),predictions[0:50],label="Prediction")
plt.legend()
plt.show()

# %%
# df.to_csv("processed.csv",index=False)

# %%
print(X)
# Out:
#       Humidity  Temperature     CO    NO2   SO2  PM2.5
# 79        26.0         27.1   3.89  27.00  1.94  48.59
# 80        43.0         27.9  11.29  22.39  2.05  47.38
# 81        43.0         27.9   9.95  26.35  6.30  65.65
# 82        43.0         27.9   1.46  29.87  6.07  60.47
# 83        43.0         27.9  10.05  23.57  4.98  62.56
# ...        ...          ...    ...    ...   ...    ...
# 2004      78.0         24.4   0.67  13.68  7.29  16.60
# 2005      74.0         24.7   0.66  10.33  6.60  20.44
# 2006      74.0         24.7   0.56  12.12  6.33  28.68
# 2007      74.0         24.7   0.56  12.69  6.45  14.47
# 2008      74.0         24.7   0.54  13.25  6.66  17.50
#
# [1846 rows x 6 columns]

# %%
print(X_test.dtypes)
# Out:
# Humidity       float64
# Temperature    float64
# CO             float64
# NO2            float64
# SO2            float64
# PM2.5          float64
# dtype: object

# %%
sample=rf_random.predict([[26,27.1,3.89,27,1.94,48.59]])
print(sample)
#sample=rf_random.predict('PM2.5':48.59,'NO2':27,'NOx':18.04,'NH3':28.02,'CO':3.89,'SO2':1.94,'Temperature':27.1,'Humidity':26])
# Out:
# [125.03936782]
# c:\users\abhis\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
# open a file to store the data
file = open('random_forest_regression_model_V2.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
file.close()
